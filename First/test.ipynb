# %%
from processData import *

# %%
from NaiveBayes import NaiveBayes

# %%
# main example
data = load_data('TP1_train.tsv')
x = divideTrainingAndValidation(data[0],data[1],0.7)
y1 = gaussianNbResult(x[0],x[1],x[2],x[3])
z1 = supportVectorMachineResult(x[0],x[1],x[2],x[3])

print(y1, z1)
# Out:
# 0.9251336898395722 0.9732620320855615

# %%
(X_train, y_train, mean_train, std_train) = load_data('TP1_train.tsv')
X_train = (X_train - mean_train)/std_train
(X_train, X_val, y_train, y_val) = train_test_split(X_train, y_train, test_size=0.33, random_state=42, stratify=y_train )
y2 = gaussianNbResult(X_train, y_train, X_val, y_val)
z2 = supportVectorMachineResult(X_train, y_train, X_val, y_val)

print(y2, z2)
# Out:
# 0.9053398058252428 0.941747572815534

# %%
nb = NaiveBayes()
nb.fit(X_train, y_train)
# Out:
# in fit

# %%
t_val = nb.predict(X_val)
# Out:
# in predict
# in _joint_log_likelihood
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# in kernel_gaussian
# ...

# %%
y3 = score(y_val, t_val)

# %%
z3 = None
print(y3, z3)
